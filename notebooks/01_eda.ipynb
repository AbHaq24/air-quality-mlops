# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("../data/raw/air_quality.csv")

df.head()
# Out:
#                time  pm2_5  pm10  carbon_monoxide  nitrogen_dioxide  \
# 0  2026-07-10T00:00   10.3  15.5            245.0              14.2
# 1  2026-07-10T01:00    9.2  14.0            196.0              12.0
# 2  2026-07-10T02:00    8.2  12.4            161.0              10.4
# 3  2026-07-10T03:00    7.6  11.5            143.0               9.7
# 4  2026-07-10T04:00    7.4  11.3            138.0               9.6
#
#    sulphur_dioxide  ozone
# 0              4.8   33.0
# 1              4.5   33.0
# 2              4.3   33.0
# 3              4.4   32.0
# 4              4.7   30.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   time              1560 non-null   str
#  1   pm2_5             1554 non-null   float64
#  2   pm10              1554 non-null   float64
#  3   carbon_monoxide   1554 non-null   float64
#  4   nitrogen_dioxide  1554 non-null   float64
#  5   sulphur_dioxide   1554 non-null   float64
#  6   ozone             1554 non-null   float64
# dtypes: float64(6), str(1)
# memory usage: 85.4 KB

# %%
### Data inspection
